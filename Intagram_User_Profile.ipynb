# %%
import pandas as pd
import json
from os import listdir
from os.path import isfile, isdir

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def ls1(path):    
    return [obj for obj in listdir(path) if isfile(path + obj)]

# %%
data =[]
files=ls1("C:/Users/Hammer/Jupyter/profiles/")
for file in files:
    data.append(file)

# %%
rutas =[]
for i in data:
    ruta = 'profiles/'+i
    rutas.append(ruta)

# %%
datw=[]
for i in rutas:
    with open(i, 'rb') as f:
        da = json.load(f)
        datw.append(da)

# %%
df = pd.DataFrame.from_dict(datw, orient='columns')

# %%
df[:30]
# Out:
#                         alias                      username  \
# 0                  1misssmeis  Sylvie Meis Official Account
# 1                      3ala2o                  Alaa Ebrahim
# 2                         433       433 | Football (Soccer)
# 3              6senseofficial                        6Sense
# 4                     7ikhals                          None
# 5                  a.sharif92                  Ahmed Sharif
# 6               aaronsanimals                 aaron benitez
# 7                  abanddoned              Abandoned Places
# 8        achievetheimpossible        Achieve the Impossible
# 9                    adenorah                      Adenorah
# 10             adesignersmind             A Designer's Mind
# 11  adingattamimi_photography                Ading Attamimi
# 12              adriancmurray              Adrian C. Murray
# 13              afnan_albatel                  افنان الباتل
# 14                      afofa    مدونة مستكة 🔶 Mestaka Blog
# 15           aguynamedpatrick               Patrick Janelle
# 16                ahmet.erdem                   Ahmet ERDEM
# 17              aialahernando                Aiala Hernando
# 18                aka.the.one                  LUNA I'NOOR🌙
# 19                    akusepp                       AKUsepp
# 20                aleksmusika                  Aleks Musika
# 21          alenaakhmadullina             alenaakhmadullina
# 22     alessandro_carpentiero        Alessandro Carpentiero
# 23                alessioalbi                  Alessio Albi
# 24             alexandrabring               ALEXANDRA BRING
# 25            alexandreagarza                    Alex Garza
# 26                alexcentomo                  Alex Centomo
# 27                alexhonnold                  Alex Honnold
# 28                alexiarayee                   Alexia Raye
# 29                  alexisren                    ALEXIS REN
#
#                                    descriptionProfile  \
# 0   [TV Host Let's Dance for RTL Germany / SBS6 / ...
# 1   [Youtuber/Gamer/Vlogger/Business owner . Snapc...
# 2   [✖️ Contact: hello@by433.com ✖️ Inquiries: sal...
# 3   [La nostra missione? Cercare di stupirti, moti...
# 4                        [Mobile snaps, Mobile snaps]
# 5   [Snapchat : ahmed_sharif92 Business inquiries ...
# 6   [I make videos with animals. New mugs:, I make...
# 7                                                None
# 8   [For all of us who have been told our deepest ...
# 9   [Anne-Laure Mais - Paris 🇫🇷 ✉️ email : adenor@...
# 10  [Architecture, interiors and lifestyle design....
# 11  [Australia & Indonesia | Traveller | Now📍Pragu...
# 12  [Father / Artist / Photographer Blog, client i...
# 13  [Independent🆎✨ Ab_web@hotm📬 snapchat👻👇🏾:iAfnan...
# 14  [اسمي :عفاف➰ مهتمة بـ إعداد الوصفات/تصويرالأطع...
# 15  [Man about town. All iPhone. patrick@aguynamed...
# 16  [Outdoor Lifestyle Photographer Istanbul/Turke...
# 17  [Photographer & Director • • ••••••••••••, Pho...
# 18  [Lifestyle VLOGS 🇦🇿🇺🇸 for business inquires lu...
# 19  [Commercial Photographer | Ruhr Area | Germany...
# 20  [Creative Director Fashion Designer @MusikaFre...
# 21  [Boutiques Moscow: 8 (495) 698 63 52 • Nikolsk...
# 22  [Travel & Architectural Photographer 📷 Italian...
# 23  [Photographer based in Italy 🇮🇹 Collaborations...
# 24  [🏋🏼‍♀️ Founder of Bring Sportswear 📩 Contact@a...
# 25  [Youtube Content Creator & Vlogger 👻:Alexandre...
# 26  [Next Models Worldwide Zürich 🔜 St. Maarten & ...
# 27  [It is what it is, and it's pretty good., It i...
# 28  [•snapchat: alexiarayee• •biochem major at UAB...
# 29  [passionately curious Lions | Storm VIII I MMX...
#
#                                            urlProfile  \
# 0               https://www.instagram.com/1misssmeis/
# 1                   https://www.instagram.com/3ala2o/
# 2                      https://www.instagram.com/433/
# 3           https://www.instagram.com/6senseofficial/
# 4                  https://www.instagram.com/7ikhals/
# 5               https://www.instagram.com/a.sharif92/
# 6            https://www.instagram.com/aaronsanimals/
# 7               https://www.instagram.com/abanddoned/
# 8     https://www.instagram.com/achievetheimpossible/
# 9                 https://www.instagram.com/adenorah/
# 10          https://www.instagram.com/adesignersmind/
# 11  https://www.instagram.com/adingattamimi_photog...
# 12           https://www.instagram.com/adriancmurray/
# 13           https://www.instagram.com/afnan_albatel/
# 14                   https://www.instagram.com/afofa/
# 15        https://www.instagram.com/aguynamedpatrick/
# 16             https://www.instagram.com/ahmet.erdem/
# 17           https://www.instagram.com/aialahernando/
# 18             https://www.instagram.com/aka.the.one/
# 19                 https://www.instagram.com/akusepp/
# 20             https://www.instagram.com/aleksmusika/
# 21       https://www.instagram.com/alenaakhmadullina/
# 22  https://www.instagram.com/alessandro_carpentiero/
# 23             https://www.instagram.com/alessioalbi/
# 24          https://www.instagram.com/alexandrabring/
# 25         https://www.instagram.com/alexandreagarza/
# 26             https://www.instagram.com/alexcentomo/
# 27             https://www.instagram.com/alexhonnold/
# 28             https://www.instagram.com/alexiarayee/
# 29               https://www.instagram.com/alexisren/
#
#                                         urlImgProfile  \
# 0   https://scontent.cdninstagram.com/t51.2885-19/...
# 1   https://scontent.cdninstagram.com/t51.2885-19/...
# 2   https://scontent.cdninstagram.com/t51.2885-19/...
# 3   https://scontent.cdninstagram.com/t51.2885-19/...
# 4   https://scontent.cdninstagram.com/t51.2885-19/...
# 5   https://scontent.cdninstagram.com/t51.2885-19/...
# 6   https://scontent.cdninstagram.com/t51.2885-19/...
# 7   https://scontent.cdninstagram.com/t51.2885-19/...
# 8   https://scontent.cdninstagram.com/t51.2885-19/...
# 9   https://scontent.cdninstagram.com/t51.2885-19/...
# 10  https://scontent.cdninstagram.com/t51.2885-19/...
# 11  https://scontent.cdninstagram.com/t51.2885-19/...
# 12  https://scontent.cdninstagram.com/t51.2885-19/...
# 13  https://scontent.cdninstagram.com/t51.2885-19/...
# 14  https://scontent.cdninstagram.com/t51.2885-19/...
# 15  https://scontent.cdninstagram.com/t51.2885-19/...
# 16  https://scontent.cdninstagram.com/t51.2885-19/...
# 17  https://scontent.cdninstagram.com/t51.2885-19/...
# 18  https://scontent.cdninstagram.com/t51.2885-19/...
# 19  https://scontent.cdninstagram.com/t51.2885-19/...
# 20  https://scontent.cdninstagram.com/t51.2885-19/...
# 21  https://scontent.cdninstagram.com/t51.2885-19/...
# 22  https://scontent.cdninstagram.com/t51.2885-19/...
# 23  https://scontent.cdninstagram.com/t51.2885-19/...
# 24  https://scontent.cdninstagram.com/t51.2885-19/...
# 25  https://scontent.cdninstagram.com/t51.2885-19/...
# 26  https://scontent.cdninstagram.com/t51.2885-19/...
# 27  https://scontent.cdninstagram.com/t51.2885-19/...
# 28  https://scontent.cdninstagram.com/t51.2885-19/...
# 29  https://scontent.cdninstagram.com/t51.2885-19/...
#
#                                               website  numberPosts  \
# 0                                   www.sylviemeis.de          988
# 1                 www.youtube.com/watch?v=MXkqzeIlhSQ          938
# 2                                   onelink.to/q6w524         6009
# 3                     www.facebook.com/6senseofficial         3324
# 4                                instagram.com/ikhals         1444
# 5                                                None          136
# 6                                   bit.do/michaelmug          114
# 7                                instagr.am/placeswow          266
# 8                            instagram.com/peterjbone         3927
# 9                                    www.adenorah.com         1963
# 10                                               None        15890
# 11                              www.adingattamimi.com         1747
# 12                                     bit.ly/2oylzJD          771
# 13                                      goo.gl/an72nQ         8194
# 14                      www.mestaka.com/?page_id=7138          521
# 15                               theliquorcabinet.com         4495
# 16                                  ahmeterdem.com.tr         3259
# 17                                  aialahernando.com         1397
# 18                                               None          246
# 19                               facebook.com/akusepp          830
# 20                                Www.MusikaFrere.coM          527
# 21                         alenaakhmadullina.ru/store         4609
# 22                          AlessandroCarpentiero.com          435
# 23  www.bottegaimmagine.it/workshop-ritratto-creativo         1530
# 24                                  alexandrabring.se         1141
# 25                               youtu.be/c1VZt31fIAQ          756
# 26                               youtu.be/eTdJaSXfklw          583
# 27                     alexhonnold.com/aloneonthewall          337
# 28                               twitch.tv/alexiaraye          614
# 29                                               None          367
#
#     numberFollowers  numberFollowing  private  \
# 0            720979              233    False
# 1            792886              466    False
# 2          14545102              433    False
# 3            243094                0    False
# 4            219458              221    False
# 5           1997133              168    False
# 6            629547              166    False
# 7            251053               11    False
# 8            938263               52    False
# 9            266992              716    False
# 10          1262267              415    False
# 11           153359              327    False
# 12           149585              634    False
# 13          6437469                4    False
# 14           248861              951    False
# 15           455333              802    False
# 16           830516              205    False
# 17           173163              167    False
# 18           166993              142    False
# 19           282224              241    False
# 20           177199              494    False
# 21           130406              535    False
# 22           322696              126    False
# 23           237945              498    False
# 24           654661              169    False
# 25           217445              411    False
# 26          1066946              187    False
# 27           506061              116    False
# 28           246491              118    False
# 29          8803856              302    False
#
#                                                 posts videos
# 0   [{'url': 'https://www.instagram.com/p/BTdS7XgB...    NaN
# 1   [{'url': 'https://www.instagram.com/p/BTbS2awF...    NaN
# 2   [{'url': 'https://www.instagram.com/p/BTgubC7A...    NaN
# 3   [{'url': 'https://www.instagram.com/p/BTem8bug...    NaN
# 4   [{'url': 'https://www.instagram.com/p/BTbOkGMg...    NaN
# 5   [{'url': 'https://www.instagram.com/p/BTEH7_1j...    NaN
# 6   [{'url': 'https://www.instagram.com/p/BTBdUG2B...    NaN
# 7   [{'url': 'https://www.instagram.com/p/BRa0MnVj...    NaN
# 8   [{'url': 'https://www.instagram.com/p/BTgm3aYh...    NaN
# 9   [{'url': 'https://www.instagram.com/p/BTg-9D5h...    NaN
# 10  [{'url': 'https://www.instagram.com/p/BThkEvAF...    NaN
# 11  [{'url': 'https://www.instagram.com/p/BTiWcoKA...    NaN
# 12  [{'url': 'https://www.instagram.com/p/BThAVx0A...    NaN
# 13  [{'url': 'https://www.instagram.com/p/BTfMRp-h...    NaN
# 14  [{'url': 'https://www.instagram.com/p/BSGLZmEA...    NaN
# 15  [{'url': 'https://www.instagram.com/p/BTiMotoF...    NaN
# 16  [{'url': 'https://www.instagram.com/p/BThQSQ6B...    NaN
# 17  [{'url': 'https://www.instagram.com/p/BSaSC0Sj...    NaN
# 18  [{'url': 'https://www.instagram.com/p/BTaMxtYh...    NaN
# 19  [{'url': 'https://www.instagram.com/p/BTb4DCqA...    NaN
# 20  [{'url': 'https://www.instagram.com/p/BTZmThwF...    NaN
# 21  [{'url': 'https://www.instagram.com/p/BTicwG3B...    NaN
# 22  [{'url': 'https://www.instagram.com/p/BTZQwepg...    NaN
# 23  [{'url': 'https://www.instagram.com/p/BTXHT03l...    NaN
# 24  [{'url': 'https://www.instagram.com/p/BTdp_pcj...    NaN
# 25  [{'url': 'https://www.instagram.com/p/BTh0UYMF...    NaN
# 26  [{'url': 'https://www.instagram.com/p/BThJx9qF...    NaN
# 27  [{'url': 'https://www.instagram.com/p/BTg5anFh...    NaN
# 28  [{'url': 'https://www.instagram.com/p/BTe_DhyD...    NaN
# 29  [{'url': 'https://www.instagram.com/p/BThKEfuD...    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978 entries, 0 to 977
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   alias               978 non-null    object
#  1   username            966 non-null    object
#  2   descriptionProfile  955 non-null    object
#  3   urlProfile          978 non-null    object
#  4   urlImgProfile       978 non-null    object
#  5   website             865 non-null    object
#  6   numberPosts         978 non-null    int64
#  7   numberFollowers     978 non-null    int64
#  8   numberFollowing     978 non-null    int64
#  9   private             978 non-null    bool
#  10  posts               978 non-null    object
#  11  videos              5 non-null      object
# dtypes: bool(1), int64(3), object(8)
# memory usage: 85.1+ KB
